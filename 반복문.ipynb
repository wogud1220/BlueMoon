# %%
sum = 0
for x in [1, 3, 5, 7, 9]:
    sum = sum + x
    print(sum, end=" ")
# Out:
# 1 4 9 16 25

# %%
list = [24.9, 29.3, 28.3, 29.9, 29.6, 32.5, 29.7, 26.3, 31.8, 34.3,
36.0, 28.0, 24.9, 31.4, 33.9, 28.9, 29.6, 24.8, 29.8, 31.2,
29.6, 31.7, 32.1, 24.4, 26.4, 30.0, 30.0, 31.2, 28.8, 33.1]
total = 0
for t in list:
    total = total + t
average = total / len(list)
print("평균 기온 %6.1f" % average)
# Out:
# 평균 기온   29.7
